#   inflating: data/test/681.png
#   inflating: data/test/682.png
#   inflating: data/test/683.png
#   inflating: data/test/684.png
#   inflating: data/test/685.png
#   inflating: data/test/686.png
#   inflating: data/test/687.png
#   inflating: data/test/688.png
#   inflating: data/test/689.png
#   inflating: data/test/69.png
#   inflating: data/test/690.png
#   inflating: data/test/691.png
#   inflating: data/test/692.png
#   inflating: data/test/693.png
#   inflating: data/test/694.png
#   inflating: data/test/695.png
#   inflating: data/test/696.png
#   inflating: data/test/697.png
#  extracting: data/test/698.png
#   inflating: data/test/699.png
#   inflating: data/test/7.png
#   inflating: data/test/70.png
#   inflating: data/test/700.png
#   inflating: data/test/701.png
#   inflating: data/test/702.png
#   inflating: data/test/703.png
#   inflating: data/test/704.png
#   inflating: data/test/705.png
#   inflating: data/test/706.png
#   inflating: data/test/707.png
#  extracting: data/test/708.png
#   inflating: data/test/709.png
#   inflating: data/test/71.png
#   inflating: data/test/710.png
#   inflating: data/test/711.png
#   inflating: data/test/712.png
#   inflating: data/test/713.png
#   inflating: data/test/714.png
#   inflating: data/test/715.png
#   inflating: data/test/716.png
#   inflating: data/test/717.png
#   inflating: data/test/718.png
#   inflating: data/test/719.png
#   inflating: data/test/72.png
#   inflating: data/test/720.png
#   inflating: data/test/721.png
#   inflating: data/test/722.png
#   inflating: data/test/723.png
#   inflating: data/test/724.png
#  extracting: data/test/725.png
#   inflating: data/test/726.png
#   inflating: data/test/727.png
#   inflating: data/test/728.png
#   inflating: data/test/729.png
#  extracting: data/test/73.png
#   inflating: data/test/730.png
#   inflating: data/test/731.png
#   inflating: data/test/732.png
#   inflating: data/test/733.png
#   inflating: data/test/734.png
#   inflating: data/test/735.png
#   inflating: data/test/736.png
#   inflating: data/test/737.png
#   inflating: data/test/738.png
#   inflating: data/test/739.png
#   inflating: data/test/74.png
#   inflating: data/test/740.png
#   inflating: data/test/741.png
#   inflating: data/test/742.png
#   inflating: data/test/743.png
#   inflating: data/test/744.png
#   inflating: data/test/745.png
#   inflating: data/test/746.png
#   inflating: data/test/747.png
#   inflating: data/test/748.png
#  extracting: data/test/749.png
#  extracting: data/test/75.png
#   inflating: data/test/750.png
#   inflating: data/test/751.png
#  extracting: data/test/752.png
#  extracting: data/test/753.png
#   inflating: data/test/754.png
#   inflating: data/test/755.png
#   inflating: data/test/756.png
#   inflating: data/test/757.png
#   inflating: data/test/758.png
#   inflating: data/test/759.png
#   inflating: data/test/76.png
#   inflating: data/test/760.png
#   inflating: data/test/761.png
#   inflating: data/test/762.png
#   inflating: data/test/763.png
#  extracting: data/test/764.png
#  extracting: data/test/765.png
#   inflating: data/test/766.png
#   inflating: data/test/767.png
#   inflating: data/test/768.png
#   inflating: data/test/769.png
#   inflating: data/test/77.png
#   inflating: data/test/770.png
#  extracting: data/test/771.png
#   inflating: data/test/772.png
#  extracting: data/test/773.png
#  extracting: data/test/774.png
#   inflating: data/test/775.png
#   inflating: data/test/776.png
#  extracting: data/test/777.png
#   inflating: data/test/778.png
#  extracting: data/test/779.png
#   inflating: data/test/78.png
#   inflating: data/test/780.png
#   inflating: data/test/781.png
#   inflating: data/test/782.png
#   inflating: data/test/783.png
#  extracting: data/test/784.png
#   inflating: data/test/785.png
#   inflating: data/test/786.png
#   inflating: data/test/787.png
#   inflating: data/test/788.png
#   inflating: data/test/789.png
#   inflating: data/test/79.png
#   inflating: data/test/790.png
#  extracting: data/test/791.png
#   inflating: data/test/792.png
#   inflating: data/test/793.png
#   inflating: data/test/794.png
#   inflating: data/test/795.png
#   inflating: data/test/796.png
#   inflating: data/test/797.png
#   inflating: data/test/798.png
#   inflating: data/test/799.png
#   inflating: data/test/8.png
#   inflating: data/test/80.png
#   inflating: data/test/800.png
#   inflating: data/test/801.png
#   inflating: data/test/802.png
#   inflating: data/test/803.png
#   inflating: data/test/804.png
#   inflating: data/test/805.png
#  extracting: data/test/806.png
#   inflating: data/test/807.png
#   inflating: data/test/808.png
#   inflating: data/test/809.png
#   inflating: data/test/81.png
#   inflating: data/test/810.png
#   inflating: data/test/811.png
#   inflating: data/test/812.png
#   inflating: data/test/813.png
#  extracting: data/test/814.png
#   inflating: data/test/815.png
#   inflating: data/test/816.png
#   inflating: data/test/817.png
#   inflating: data/test/818.png
#   inflating: data/test/819.png
#   inflating: data/test/82.png
#   inflating: data/test/820.png
#   inflating: data/test/821.png
#   inflating: data/test/822.png
#   inflating: data/test/823.png
#   inflating: data/test/824.png
#   inflating: data/test/825.png
#   inflating: data/test/826.png
#   inflating: data/test/827.png
#   inflating: data/test/828.png
#   inflating: data/test/829.png
#   inflating: data/test/83.png
#   inflating: data/test/830.png
#   inflating: data/test/831.png
#   inflating: data/test/832.png
#   inflating: data/test/833.png
#   inflating: data/test/834.png
#  extracting: data/test/835.png
#   inflating: data/test/836.png
#   inflating: data/test/837.png
#   inflating: data/test/838.png
#   inflating: data/test/839.png
#   inflating: data/test/84.png
#   inflating: data/test/840.png
#   inflating: data/test/841.png
#   inflating: data/test/842.png
#   inflating: data/test/843.png
#   inflating: data/test/844.png
#   inflating: data/test/845.png
#   inflating: data/test/846.png
#   inflating: data/test/847.png
#   inflating: data/test/848.png
#   inflating: data/test/849.png
#   inflating: data/test/85.png
#   inflating: data/test/850.png
#   inflating: data/test/851.png
#   inflating: data/test/852.png
#   inflating: data/test/853.png
#   inflating: data/test/854.png
#   inflating: data/test/855.png
#   inflating: data/test/856.png
#   inflating: data/test/857.png
#   inflating: data/test/858.png
#   inflating: data/test/859.png
#   inflating: data/test/86.png
#   inflating: data/test/860.png
#   inflating: data/test/861.png
#   inflating: data/test/862.png
#  extracting: data/test/863.png
#  extracting: data/test/864.png
#   inflating: data/test/865.png
#   inflating: data/test/866.png
#   inflating: data/test/867.png
#   inflating: data/test/868.png
#  extracting: data/test/869.png
#   inflating: data/test/87.png
#   inflating: data/test/870.png
#   inflating: data/test/871.png
#  extracting: data/test/872.png
#  extracting: data/test/873.png
#   inflating: data/test/874.png
#   inflating: data/test/875.png
#  extracting: data/test/876.png
#   inflating: data/test/877.png
#   inflating: data/test/878.png
#  extracting: data/test/879.png
#   inflating: data/test/88.png
#   inflating: data/test/880.png
#   inflating: data/test/881.png
#   inflating: data/test/882.png
#   inflating: data/test/883.png
#   inflating: data/test/884.png
#   inflating: data/test/885.png
#   inflating: data/test/886.png
#   inflating: data/test/887.png
#   inflating: data/test/888.png
#   inflating: data/test/889.png
#  extracting: data/test/89.png
#   inflating: data/test/890.png
#   inflating: data/test/891.png
#   inflating: data/test/892.png
#  extracting: data/test/893.png
#   inflating: data/test/894.png
#  extracting: data/test/895.png
#   inflating: data/test/896.png
#   inflating: data/test/897.png
#   inflating: data/test/898.png
#  extracting: data/test/899.png
#  extracting: data/test/9.png
#   inflating: data/test/90.png
#   inflating: data/test/900.png
#  extracting: data/test/901.png
#   inflating: data/test/902.png
#   inflating: data/test/903.png
#  extracting: data/test/904.png
#   inflating: data/test/905.png
#   inflating: data/test/906.png
#   inflating: data/test/907.png
#   inflating: data/test/908.png
#   inflating: data/test/909.png
#   inflating: data/test/91.png
#   inflating: data/test/910.png
#   inflating: data/test/911.png
#   inflating: data/test/912.png
#   inflating: data/test/913.png
#   inflating: data/test/914.png
#   inflating: data/test/915.png
#   inflating: data/test/916.png
#   inflating: data/test/917.png
#   inflating: data/test/918.png
#   inflating: data/test/919.png
#   inflating: data/test/92.png
#   inflating: data/test/920.png
#   inflating: data/test/921.png
#   inflating: data/test/922.png
#   inflating: data/test/923.png
#  extracting: data/test/924.png
#   inflating: data/test/925.png
#   inflating: data/test/926.png
#   inflating: data/test/927.png
#   inflating: data/test/928.png
#   inflating: data/test/929.png
#   inflating: data/test/93.png
#   inflating: data/test/930.png
#   inflating: data/test/931.png
#   inflating: data/test/932.png
#   inflating: data/test/933.png
#   inflating: data/test/934.png
#   inflating: data/test/935.png
#   inflating: data/test/936.png
#   inflating: data/test/937.png
#   inflating: data/test/938.png
#   inflating: data/test/939.png
#   inflating: data/test/94.png
#   inflating: data/test/940.png
#   inflating: data/test/941.png
#   inflating: data/test/942.png
#   inflating: data/test/943.png
#   inflating: data/test/944.png
#   inflating: data/test/945.png
#   inflating: data/test/946.png
#   inflating: data/test/947.png
#   inflating: data/test/948.png
#   inflating: data/test/949.png
#   inflating: data/test/95.png
#   inflating: data/test/950.png
#   inflating: data/test/951.png
#   inflating: data/test/952.png
#   inflating: data/test/953.png
#   inflating: data/test/954.png
#   inflating: data/test/955.png
#   inflating: data/test/956.png
#   inflating: data/test/957.png
#   inflating: data/test/958.png
#   inflating: data/test/959.png
#   inflating: data/test/96.png
#   inflating: data/test/960.png
#   inflating: data/test/961.png
#   inflating: data/test/962.png
#   inflating: data/test/963.png
#   inflating: data/test/964.png
#   inflating: data/test/965.png
#   inflating: data/test/966.png
#   inflating: data/test/967.png
#   inflating: data/test/968.png
#   inflating: data/test/969.png
#   inflating: data/test/97.png
#   inflating: data/test/970.png
#   inflating: data/test/971.png
#   inflating: data/test/972.png
#   inflating: data/test/973.png
#   inflating: data/test/974.png
#   inflating: data/test/975.png
#   inflating: data/test/976.png
#   inflating: data/test/977.png
#   inflating: data/test/978.png
#   inflating: data/test/979.png
#   inflating: data/test/98.png
#   inflating: data/test/980.png
#   inflating: data/test/981.png
#   inflating: data/test/982.png
#   inflating: data/test/983.png
#   inflating: data/test/984.png
#   inflating: data/test/985.png
#   inflating: data/test/986.png
#   inflating: data/test/987.png
#   inflating: data/test/988.png
#   inflating: data/test/989.png
#   inflating: data/test/99.png
#   inflating: data/test/990.png
#   inflating: data/test/991.png
#   inflating: data/test/992.png
#   inflating: data/test/993.png
#   inflating: data/test/994.png
#   inflating: data/test/995.png
#   inflating: data/test/996.png
#   inflating: data/test/997.png
#   inflating: data/test/998.png
#   inflating: data/test/999.png

# %%
import os, torch, copy, cv2, sys, random, logging
from datetime import datetime, timezone, timedelta
from PIL import Image
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

# %%
def get_logger(name: str, file_path: str, stream=False) -> logging.RootLogger:
    logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)

    formatter = logging.Formatter('%(asctime)s | %(name)s | %(levelname)s | %(message)s')
    stream_handler = logging.StreamHandler()
    file_handler = logging.FileHandler(file_path)

    stream_handler.setFormatter(formatter)
    file_handler.setFormatter(formatter)

    if stream:
        logger.addHandler(stream_handler)
    logger.addHandler(file_handler)

    return logger

# %% [markdown]
# ## Argument Setting

# %%
# 시드(seed) 설정

RANDOM_SEED = 2021
torch.manual_seed(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# %%
# working directory 지정
ROOT_PATH = './data'
DATA_DIR = os.path.join(ROOT_PATH, 'train')
RESULT_DIR = os.path.join(ROOT_PATH, 'result')
if not os.path.isdir(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# hyper-parameters
EPOCHS = 1
BATCH_SIZE = 16
LEARNING_RATE = 0.0005
EARLY_STOPPING_PATIENCE = 5
INPUT_SHAPE = (180, 90)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Dataloader

# %% [markdown]
# #### Train & Validation Set loader

# %%
class CustomDataset(Dataset):
    def __init__(self, data_dir, mode, input_shape):

        self.data_dir = data_dir
        self.mode = mode
        self.input_shape = input_shape
        
        if os.path.isfile(os.path.join(RESULT_DIR, 'total.pkl')):
            self.db = pd.read_pickle(os.path.join(RESULT_DIR, 'total.pkl'))
        else:
            self.db = self.data_loader()
            self.db = self.db.sample(frac=1).reset_index()
            self.db.to_pickle(os.path.join(RESULT_DIR, 'total.pkl'))
            
        if self.mode == 'train':
            self.db = self.db[:int(len(self.db) * 0.9)]
        elif self.mode == 'val':
            self.db = self.db[int(len(self.db) * 0.9):]
            self.db.reset_index(inplace=True)
        else:
            print(f'!!! Invalid split {self.mode}... !!!')
        self.transform = transforms.Compose([transforms.Resize(self.input_shape), transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
    
    def data_loader(self):
        print('Loading ' + self.mode + ' dataset..')
        if not os.path.isdir(self.data_dir):
            print(f'!!! Cannot find {self.data_dir}... !!!')
            sys.exit()
            
        mask_image_list = os.listdir(os.path.join(self.data_dir, 'Mask'))
        nomask_image_list = os.listdir(os.path.join(self.data_dir, 'NoMask'))
        mask_image_list = [item for item in mask_image_list if item[-4:] == '.png']
        nomask_image_list = [item for item in nomask_image_list  if item[-4:] == '.png']
        mask_image_path = list(map(lambda x : os.path.join(self.data_dir, 'Mask', x), mask_image_list))
        nomask_image_path = list(map(lambda x : os.path.join(self.data_dir, 'NoMask', x), nomask_image_list))

        # encoding label (Mask : 1, No Mask : 0)
        mask_df = pd.DataFrame({'img_path':mask_image_path, 'label':np.ones(len(mask_image_list))})
        nomask_df = pd.DataFrame({'img_path':nomask_image_path, 'label':np.zeros(len(nomask_image_list))})
        db = mask_df.append(nomask_df, ignore_index=True)
        return db

    def __len__(self):
        return len(self.db)

    def __getitem__(self, index):
        data = copy.deepcopy(self.db.loc[index])

        # Loading image
        cvimg = cv2.imread(data['img_path'], cv2.IMREAD_COLOR | cv2.IMREAD_IGNORE_ORIENTATION)
        if not isinstance(cvimg, np.ndarray):
            raise IOError("Fail to read %s" % data['img_path'])

        # Preprocessing images
        trans_image = self.transform(Image.fromarray(cvimg))

        return trans_image, data['label']

# %% [markdown]
# ## Model

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=588854bfc837ad42c7815d7380d6e51c08ffb255a6ca0f0a3c722f1b9d660ccc
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
from torch.nn import functional as F
from efficientnet_pytorch import EfficientNet

class MaskClassifier(nn.Module):
    def __init__(self):
        super(MaskClassifier, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=2)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, input_img):
        x = self.model(input_img)
        x = self.softmax(x)
        return x

# %% [markdown]
# ## EarlyStopper

# %%
class LossEarlyStopper():
    """Early stopper
    
    Attributes:
        patience (int): loss가 줄어들지 않아도 학습할 epoch 수
        verbose (bool): 로그 출력 여부, True 일 때 로그 출력
        patience_counter (int): loss 가 줄어들지 않을 때 마다 1씩 증가
        min_loss (float): 최소 loss
        stop (bool): True 일 때 학습 중단

    """

    def __init__(self, patience: int, verbose: bool, logger:logging.RootLogger=None)-> None:
        """ 초기화

        Args:
            patience (int): loss가 줄어들지 않아도 학습할 epoch 수
            weight_path (str): weight 저장경로
            verbose (bool): 로그 출력 여부, True 일 때 로그 출력
        """
        self.patience = patience
        self.verbose = verbose

        self.patience_counter = 0
        self.min_loss = np.Inf
        self.logger = logger
        self.stop = False

    def check_early_stopping(self, loss: float)-> None:
        """Early stopping 여부 판단

        Args:
            loss (float):

        Examples:
            
        Note:
            
        """  

        if self.min_loss == np.Inf:
            self.min_loss = loss
            # self.save_checkpoint(loss=loss, model=model)

        elif loss > self.min_loss:
            self.patience_counter += 1
            msg = f"Early stopper, Early stopping counter {self.patience_counter}/{self.patience}"

            if self.patience_counter == self.patience:
                self.stop = True

            if self.verbose:
                self.logger.info(msg) if self.logger else print(msg)
                
        elif loss <= self.min_loss:
            self.save_model = True
            msg = f"Early stopper, Validation loss decreased {self.min_loss} -> {loss}"
            self.min_loss = loss
            # self.save_checkpoint(loss=loss, model=model)

            if self.verbose:
                self.logger.info(msg) if self.logger else print(msg)

# %% [markdown]
# ## Trainer

# %%
class Trainer():
    """ Trainer
        epoch에 대한 학습 및 검증 절차 정의
    """
    def __init__(self, criterion, model, device, metric_fn, optimizer=None, scheduler=None, logger=None):
        """ 초기화
        """
        self.criterion = criterion
        self.model = model
        self.device = device
        self.optimizer = optimizer
        self.logger = logger
        self.scheduler = scheduler
        self.metric_fn = metric_fn

    def train_epoch(self, dataloader, epoch_index):
        """ 한 epoch에서 수행되는 학습 절차
        """
        self.model.train()
        train_total_loss = 0
        target_lst = []
        pred_lst = []
        prob_lst = []

        for batch_index, (img, label) in enumerate(dataloader):
            img = img.to(self.device)
            label = label.to(self.device).long()
            pred = self.model(img)
            loss = self.criterion(pred, label)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            self.scheduler.step()
            train_total_loss += loss.item()
            prob_lst.extend(pred[:, 1].cpu().tolist())
            target_lst.extend(label.cpu().tolist())
            pred_lst.extend(pred.argmax(dim=1).cpu().tolist())
        self.train_mean_loss = train_total_loss / batch_index
        self.train_score, auroc = self.metric_fn(y_pred=pred_lst, y_answer=target_lst, y_prob=prob_lst)
        msg = f'Epoch {epoch_index}, Train loss: {self.train_mean_loss}, Acc: {self.train_score}, ROC: {auroc}'
        print(msg)

    def validate_epoch(self, dataloader, epoch_index):
        """ 한 epoch에서 수행되는 검증 절차
        """
        self.model.eval()
        val_total_loss = 0
        target_lst = []
        pred_lst = []
        prob_lst = []

        for batch_index, (img, label) in enumerate(dataloader):
            img = img.to(self.device)
            label = label.to(self.device).long()
            pred = self.model(img)
            ## coordinate loss
            loss = self.criterion(pred, label)
            val_total_loss += loss.item()
            prob_lst.extend(pred[:, 1].cpu().tolist())
            target_lst.extend(label.cpu().tolist())
            pred_lst.extend(pred.argmax(dim=1).cpu().tolist())
        self.val_mean_loss = val_total_loss / batch_index
        self.validation_score, auroc = self.metric_fn(y_pred=pred_lst, y_answer=target_lst, y_prob=prob_lst)
        msg = f'Epoch {epoch_index}, Val loss: {self.val_mean_loss}, Acc: {self.validation_score}, ROC: {auroc}'
        print(msg)

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

def get_metric_fn(y_pred, y_answer, y_prob):
    """ 성능을 반환하는 함수
    """
    assert len(y_pred) == len(y_answer), 'The size of prediction and answer are not same.'
    accuracy = accuracy_score(y_answer, y_pred)
    auroc = roc_auc_score(y_answer, y_prob)
    return accuracy, auroc

# %% [markdown]
# ## 학습을 위한 객체 선언

# %%
# Load dataset & dataloader
train_dataset = CustomDataset(data_dir=DATA_DIR, mode='train', input_shape=INPUT_SHAPE)
validation_dataset = CustomDataset(data_dir=DATA_DIR, mode='val', input_shape=INPUT_SHAPE)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=True)
print('Train set samples:',len(train_dataset),  'Val set samples:', len(validation_dataset))
# Out:
# Loading train dataset..
# Train set samples: 24388 Val set samples: 2710

# %%
# Load Model
model = MaskClassifier().to(device)

# Save Initial Model
torch.save({'model':model.state_dict()}, os.path.join(RESULT_DIR, 'initial.pt'))

# Set optimizer, scheduler, loss function, metric function
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
scheduler =  optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e5, max_lr=0.0001, epochs=EPOCHS, steps_per_epoch=len(train_dataloader))
criterion = nn.CrossEntropyLoss()
metric_fn = get_metric_fn

# Set system logger
system_logger = get_logger(name='train',file_path='train_log.log')

# Set trainer
trainer = Trainer(criterion, model, device, metric_fn, optimizer, scheduler, logger=system_logger)

# Set earlystopper
early_stopper = LossEarlyStopper(patience=EARLY_STOPPING_PATIENCE, verbose=True, logger=system_logger)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b0

# %%
criterion = 1E+8
for epoch_index in tqdm(range(EPOCHS)):

    trainer.train_epoch(train_dataloader, epoch_index)
    trainer.validate_epoch(validation_dataloader, epoch_index)

    # early_stopping check
    early_stopper.check_early_stopping(loss=trainer.val_mean_loss)

    if early_stopper.stop:
        print('Early stopped')
        break

    if trainer.val_mean_loss < criterion:
        criterion = trainer.val_mean_loss
        check_point = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict()
        }
        torch.save(check_point, os.path.join(RESULT_DIR, 'best.pt'))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0, Train loss: 0.47525321572940804, Acc: 0.8327046088240118, ROC: 0.9121604372266026
# 100%|██████████| 1/1 [02:10<00:00, 130.58s/it]
# Epoch 0, Val loss: 0.41044821841476936, Acc: 0.9059040590405905, ROC: 0.9655383851890655

# %% [markdown]
# ## Inference

# %%
TRAINED_MODEL_PATH = os.path.join(RESULT_DIR, 'best.pt')

# %% [markdown]
# #### Test set Loader

# %%
class TestDataset(Dataset):
    def __init__(self, data_dir, input_shape):
        self.data_dir = data_dir
        self.input_shape = input_shape
        
        # Loading dataset
        self.db = self.data_loader()
        
        # Transform function
        self.transform = transforms.Compose([transforms.Resize(self.input_shape), transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

    def data_loader(self):
        print('Loading test dataset..')
        if not os.path.isdir(self.data_dir):
            print(f'!!! Cannot find {self.data_dir}... !!!')
            sys.exit()
        image_list = os.listdir(self.data_dir)
        image_list = [item for item in image_list if item[-4:] == '.png']
        image_path = list(map(lambda x : os.path.join(self.data_dir, x), image_list))
        db = pd.DataFrame({'img_path':image_path, 'file_num':list(map(lambda x : x.split('.')[0], image_list))})
        return db
    
    def __len__(self):
        return len(self.db)
    
    def __getitem__(self, index):
        data = copy.deepcopy(self.db.loc[index])
        
        # Loading image
        cvimg = cv2.imread(data['img_path'], cv2.IMREAD_COLOR | cv2.IMREAD_IGNORE_ORIENTATION)
        if not isinstance(cvimg, np.ndarray):
            raise IOError("Fail to read %s" % data['img_path'])

        # Preprocessing images
        trans_image = self.transform(Image.fromarray(cvimg))

        return trans_image, data['file_num']

# %%
DATA_DIR=os.path.join(ROOT_PATH, 'test')

# Load dataset & dataloader
test_dataset = TestDataset(data_dir=DATA_DIR, input_shape=INPUT_SHAPE)
test_dataloader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Loading test dataset..

# %%
model.load_state_dict(torch.load(TRAINED_MODEL_PATH)['model'])

# Prediction
file_num_lst = []
pred_lst = []
prob_lst = []
model.eval()
with torch.no_grad():
    for batch_index, (img, file_num) in enumerate(test_dataloader):
        img = img.to(device)
        pred = model(img)
        file_num_lst.extend(list(file_num))
        pred_lst.extend(pred.argmax(dim=1).tolist())
        prob_lst.extend(pred[:, 1].tolist())

# %% [markdown]
# #### Save results as csv file

# %%
df = pd.DataFrame({'file_name':list(map(int,file_num_lst)), 'answer':pred_lst, 'prob':prob_lst})
df.sort_values(by=['file_name'], inplace=True)
df.to_csv(os.path.join(RESULT_DIR, 'mask_pred.csv'), index=False)

# %%
# !cp ./data/result/best.pt /gdrive/aicon/aicon_mask/backup/backup0/
# !cp ./data/result/initial.pt /gdrive/aicon/aicon_mask/backup/backup0/
# !cp ./data/result/mask_pred.csv /gdrive/aicon/aicon_mask/result/result0/
# !cp ./data/result/total.pkl /gdrive/aicon/aicon_mask/result/result0/
